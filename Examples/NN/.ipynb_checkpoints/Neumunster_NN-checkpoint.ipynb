# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/GaoyuanWu/JaxSSO/blob/main/Examples/Mannheim_Multihalle.ipynb)

# %%
# !pip install JaxSSO
# !pip install nlopt

# %%
import sys
sys.path.append('/home/gaoyuanw/Github/JaxSSO')
import JaxSSO.model as Model 
import JaxSSO.optimization as optimization
from JaxSSO import assemblemodel,solver
from JaxSSO.SSO_model import NodeParameter,ElementParameter,SSO_model
import numpy as np
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import pandas as pd
import json
from jax import grad,value_and_grad

# %%
#Import the geometry, mesh and fixed node info
f = open('Neumunster.json')
 
# returns JSON object as 
# a dictionary
data = json.load(f)


f.close()

df = data['faces'] #Connectivity matrix
faces = np.array(df) #convert to numpy array
df2 = data['vertices'] #Coordinate
crd = np.array(df2) #convert to numpy array
df3 = data['vertex_is_red'] #Connectivity matrix
fixed_nodes = np.where(df3)[0] #convert to numpy array

#From faces to frames
import trimesh
mesh = trimesh.load('Neumunster.ply')

cnct  = np.array(mesh.edges_unique)

# %%
#Normalize the coordinates
x_nodes = crd[:,0]-min(crd[:,0])
y_nodes = crd[:,1]-min(crd[:,1])
z_nodes = crd[:,2]-min(crd[:,2])

n_node = crd.shape[0] #number of nodes
n_ele = cnct.shape[0] #number of elements

# %%
design_nodes = [] 
for i in range(n_node):
  if i not in fixed_nodes:
    design_nodes.append(i)

fixed_nodes = np.array(fixed_nodes,dtype=int)
design_nodes = np.array(design_nodes,dtype=int)
non_design_nodes = fixed_nodes
x_ele = np.zeros((n_ele,2))
y_ele = np.zeros((n_ele,2))
z_ele = np.zeros((n_ele,2))
for i in range(n_ele):
  x_ele[i,0] = x_nodes[cnct[i,0]]
  x_ele[i,1] = x_nodes[cnct[i,1]]
  y_ele[i,0] = y_nodes[cnct[i,0]]
  y_ele[i,1] = y_nodes[cnct[i,1]]
  z_ele[i,0] = z_nodes[cnct[i,0]]
  z_ele[i,1] = z_nodes[cnct[i,1]]

design_crds = np.expand_dims(design_nodes,axis=1)
design_crds = np.hstack((design_crds,2*np.ones((design_crds.shape[0],1),dtype=int)))

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')
ax.set_zlim(0,15)
ax.set_xlabel('X (m)',fontsize=15)
ax.set_ylabel('Y (m)',fontsize=15)
ax.set_zlabel('Z (m)',fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
#Plot a basic wireframe.
for i in range(n_ele):
  ax.plot([x_ele[i,0],x_ele[i,1]],[y_ele[i,0],y_ele[i,1]],[z_ele[i,0],z_ele[i,1]],color='darkcyan')

ax.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],z_nodes[non_design_nodes],color='black',label='Non-design nodes')
ax.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],z_nodes[non_design_nodes]-0.2,s=150,marker='^',alpha=0.2,color='black')
ax.view_init(20, 45)
plt.legend(fontsize=17, loc=(0.5,0.7))
ax.grid(False)
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
plt.show()

# %%
def Linear_filter(dist,R):
    '''
    A linear filter with radius R, will be normalized later to satisfy unit-intergral condition.
    '''
    return np.where(dist>R,0,(1/R)*(R-dist))
#Matrix storing XY-projected distance  
dx_ij = x_nodes[:,None]-x_nodes[None,:]
dy_ij = y_nodes[:,None]-y_nodes[None,:]
D_ij = (dx_ij**2 + dy_ij**2)**0.5

#Create the filter mapping matrix
B_ij_ini = Linear_filter(D_ij,3)


#This does not impose any constraints on the boundary nodes.
#We apply soft constraints - increasing the weights of boundary
alpha = 1 # coefficient adujsting the weights for boundary
B_ij_ini[:,non_design_nodes] *= alpha
B_ij_sum = np.sum(B_ij_ini,axis=1)
B_ij_sum = B_ij_sum.repeat(x_nodes.shape[0]).reshape(x_nodes.shape[0],x_nodes.shape[0])
B_ij = B_ij_ini/B_ij_sum

# %%
zs_filtered = z_nodes.copy()
zs_filtered[design_nodes] =(B_ij@zs_filtered)[design_nodes]

# %%
################
#  SSO MODEL   #
################
#Build the model
#Sectional properties-> 600x400 rectangle
d = 0.1 #diameter
A = np.pi*d**2/4
Iy = np.pi*d**4/64
Iz = np.pi*d**4/64
E = 37900 * 10**5 #Young's modulus (pa)
G = E/(2*(1+0.3)) #Shear modolus-> E = 2G(1+mu)
J = Iy + Iz	#Polar moment of inertia
load = 300 #Pt load

model = Model.Model() #model for sensitivity analysis

#Adding nodes and boundary conditions
for i in range(n_node):

    model.add_node(i,x_nodes[i],y_nodes[i],z_nodes[i])
    if i not in design_nodes:
        model.add_support(i,[1,1,1,0,0,1]) #Pinned, only Ry allow
    else:
        model.add_nodal_load(i,nodal_load=[0.0,0.0,-load,0.0,0.0,0.0])

aI = 1e-10
#Adding elements
for i in range(n_ele):
    i_node = cnct[i,0]
    j_node = cnct[i,1]
    model.add_beamcol(i,i_node,j_node,E,G,aI*Iy,aI*Iz,aI*J,A)

# %%
A
# Out:
# 0.007853981633974483

# %%
# Start the SSO model
sso_model = SSO_model(model) # initial sso model
for node in design_nodes:
    nodeparameter = NodeParameter(node,2) # nodeparamter object
    sso_model.add_nodeparameter(nodeparameter)

#Initial the parameters
sso_model.initialize_parameters_values()
sso_model.set_objective(objective='strain energy',func=None,func_args=None)

# %%
# %timeit sso_model.value_grad_params(which_solver='sparse',enforce_scipy_sparse = True)
# Out:
# 314 ms ± 1.45 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
C_hist = []
def objective_filter(x,sso_model=sso_model):
    p = z_nodes.copy()
    p[design_nodes]=x
    z = (B_ij@p)[design_nodes]
    sso_model.update_nodeparameter(z) # Update the model
    C,sens = sso_model.value_grad_params(which_solver='dense',enforce_scipy_sparse = True)
    C_hist.append(C)
    return C,np.asarray((sens@B_ij[design_nodes])[design_nodes],dtype=float)#sens_params

# %%
n_x = design_nodes.shape[0] #number of parameters
x_ini = sso_model.nodeparameters_values #initial parameters 
opt = optimization.Optimization(n_x,method='GD')
opt.set_objective(objective_filter) #objective function
opt.set_maxiter(200) #max iteration
opt.set_step_size(5e-2) #step size
opt.set_GD_normalized(True) #normalized
x_opt = opt.optimize(x_ini,log=True)
# Out:
# Step 0, objective = 47801.98377230502
# Step 1, objective = 27514.057785302848
# Step 2, objective = 22578.18852657167
# Step 3, objective = 20263.350666318656
# Step 4, objective = 18231.394622052623
# Step 5, objective = 17032.366989420087
# Step 6, objective = 15698.7605841144
# Step 7, objective = 14307.328743353235
# Step 8, objective = 13400.167533132919
# Step 9, objective = 12264.002543989342
# Step 10, objective = 11704.170847786309
# Step 11, objective = 10448.923368540738
# Step 12, objective = 9968.76946195169
# Step 13, objective = 9233.700966198594
# Step 14, objective = 8712.057008961838
# Step 15, objective = 8212.291911323948
# Step 16, objective = 7507.068760928527
# Step 17, objective = 6883.572478417473
# Step 18, objective = 6315.546646657249
# Step 19, objective = 5812.905872894566
# Step 20, objective = 5353.782592348946
# Step 21, objective = 4909.352407738429
# Step 22, objective = 4505.828370046169
# Step 23, objective = 4173.05785268655
# Step 24, objective = 3922.331392307855
# Step 25, objective = 3723.4017742908472
# Step 26, objective = 3540.9160013650344
# Step 27, objective = 3358.8812947592014
# Step 28, objective = 3161.1245959138705
# Step 29, objective = 2967.637281807579
# Step 30, objective = 2841.317649803639
# Step 31, objective = 2817.1072064870073
# Step 32, objective = 2889.709824960286
# Step 33, objective = 2694.725451703152
# Step 34, objective = 2854.3656000807605
# Step 35, objective = 2601.0191321076873
# Step 36, objective = 2738.9147556296703
# Step 37, objective = 2526.879938497985
# Step 38, objective = 2710.2175794462482
# Step 39, objective = 2443.422474223179
# Step 40, objective = 2683.396998116084
# Step 41, objective = 2358.6594446001163
# Step 42, objective = 2593.686864698086
# Step 43, objective = 2286.3113630025755
# Step 44, objective = 2622.161272850322
# Step 45, objective = 2211.8052762260913
# Step 46, objective = 2457.598366571132
# Step 47, objective = 2153.641589968471
# Step 48, objective = 2597.5799523944834
# Step 49, objective = 2090.8656057747817
# Step 50, objective = 2272.592918679641
# Step 51, objective = 2071.84039450556
# Step 52, objective = 2412.5092104378987
# Step 53, objective = 2014.3963869978083
# Step 54, objective = 2552.0618726412613
# Step 55, objective = 1956.176503131413
# Step 56, objective = 1878.0231136327589
# Step 57, objective = 2059.7657760482225
# Step 58, objective = 1966.1637871781588
# Step 59, objective = 2105.5242138324393
# Step 60, objective = 1901.2939849494428
# Step 61, objective = 2202.2346715127023
# Step 62, objective = 1833.4764886190383
# Step 63, objective = 2389.631239753482
# Step 64, objective = 1791.1564803140827
# Step 65, objective = 1882.1373549192379
# Step 66, objective = 1937.1752354154164
# Step 67, objective = 1796.939260368791
# Step 68, objective = 2034.8165744016628
# Step 69, objective = 1749.997381210548
# Step 70, objective = 2092.5075990346754
# Step 71, objective = 1715.420634295931
# Step 72, objective = 2046.189343335027
# Step 73, objective = 1686.4841190425946
# Step 74, objective = 1693.9925709104523
# Step 75, objective = 1726.2044579263625
# Step 76, objective = 1704.7593324526517
# Step 77, objective = 1740.1535638108808
# Step 78, objective = 1673.5951514902172
# Step 79, objective = 1800.0066966008094
# Step 80, objective = 1650.4031024463745
# Step 81, objective = 1999.8838929863523
# Step 82, objective = 1622.5489698812867
# Step 83, objective = 1902.0129578074125
# Step 84, objective = 1603.998682727612
# Step 85, objective = 1788.8190989616273
# Step 86, objective = 1601.4265572978074
# Step 87, objective = 1730.8962834518466
# Step 88, objective = 1597.81516314287
# Step 89, objective = 1678.778213724188
# Step 90, objective = 1599.5579696235277
# Step 91, objective = 1646.521878444639
# Step 92, objective = 1605.2380158576286
# Step 93, objective = 1630.545060373264
# Step 94, objective = 1637.8874408286013
# Step 95, objective = 1676.3905117489821
# Step 96, objective = 1641.143338045043
# Step 97, objective = 1636.921228778603
# Step 98, objective = 1598.0637279496627
# Step 99, objective = 1632.9282629500833
# Step 100, objective = 1575.162606218311
# Step 101, objective = 1640.0935566950193
# Step 102, objective = 1561.0179454634344
# Step 103, objective = 1676.1811938064159
# Step 104, objective = 1552.7897463204577
# Step 105, objective = 1722.587186751724
# Step 106, objective = 1544.697835386938
# Step 107, objective = 1628.7450763865322
# Step 108, objective = 1555.5268970670975
# Step 109, objective = 1606.5392981269704
# Step 110, objective = 1580.6051671503553
# Step 111, objective = 1583.052843335925
# Step 112, objective = 1533.737174883625
# Step 113, objective = 1593.5435140405616
# Step 114, objective = 1514.876492670862
# Step 115, objective = 1617.8588103407953
# Step 116, objective = 1508.7059806205098
# Step 117, objective = 1549.096225452907
# Step 118, objective = 1515.24824454486
# Step 119, objective = 1528.729463247673
# Step 120, objective = 1532.5105175246665
# Step 121, objective = 1519.1802370238395
# Step 122, objective = 1488.2954014164202
# Step 123, objective = 1534.6870571903603
# Step 124, objective = 1478.0082815523992
# Step 125, objective = 1505.5544669991634
# Step 126, objective = 1475.8851974292338
# Step 127, objective = 1475.1462178354186
# Step 128, objective = 1489.1122025779314
# Step 129, objective = 1472.2665117649406
# Step 130, objective = 1463.3152943232967
# Step 131, objective = 1478.5247095675163
# Step 132, objective = 1449.9206650336919
# Step 133, objective = 1445.0099694583805
# Step 134, objective = 1444.364141416102
# Step 135, objective = 1419.4569830468822
# Step 136, objective = 1451.0025317374104
# Step 137, objective = 1412.4480112710555
# Step 138, objective = 1479.7489640826238
# Step 139, objective = 1395.6580069136796
# Step 140, objective = 1419.9241830265387
# Step 141, objective = 1390.3089136121475
# Step 142, objective = 1395.7047327395042
# Step 143, objective = 1462.0953141018176
# Step 144, objective = 1368.3800389836751
# Step 145, objective = 1352.9481980014752
# Step 146, objective = 1369.0092908389934
# Step 147, objective = 1379.5166110278485
# Step 148, objective = 1339.750467094686
# Step 149, objective = 1340.0880375357724
# Step 150, objective = 1339.3349036393033
# Step 151, objective = 1361.3420787890227
# Step 152, objective = 1329.946549071864
# Step 153, objective = 1370.4568409527353
# Step 154, objective = 1311.2482720958608
# Step 155, objective = 1360.2036821913125
# Step 156, objective = 1296.9643345344948
# Step 157, objective = 1361.2086357866528
# Step 158, objective = 1294.96184294759
# Step 159, objective = 1328.655625280885
# Step 160, objective = 1303.6883823449007
# Step 161, objective = 1323.7791630923166
# Step 162, objective = 1308.5717574766609
# Step 163, objective = 1311.7041067073487
# Step 164, objective = 1288.6278382933147
# Step 165, objective = 1391.0187959013695
# Step 166, objective = 1267.8078595317909
# Step 167, objective = 1285.7133825881372
# Step 168, objective = 1268.4311639762946
# Step 169, objective = 1305.1437721075165
# Step 170, objective = 1254.89232715235
# Step 171, objective = 1282.9798623594545
# Step 172, objective = 1256.1234263276638
# Step 173, objective = 1260.6474466195568
# Step 174, objective = 1244.065530335547
# Step 175, objective = 1245.146705112644
# Step 176, objective = 1257.4205121704435
# Step 177, objective = 1269.5019199690732
# Step 178, objective = 1244.1968870278274
# Step 179, objective = 1234.4247277069971
# Step 180, objective = 1245.7412213120656
# Step 181, objective = 1237.001714615004
# Step 182, objective = 1274.2277299331026
# Step 183, objective = 1230.600455573615
# Step 184, objective = 1236.2813583177401
# Step 185, objective = 1294.5803209515263
# Step 186, objective = 1224.3434837846658
# Step 187, objective = 1267.6259798664537
# Step 188, objective = 1200.6979717342363
# Step 189, objective = 1264.5535780900104
# Step 190, objective = 1197.3823401509017
# Step 191, objective = 1243.6515792339533
# Step 192, objective = 1196.1958389028391
# Step 193, objective = 1211.3154227603568
# Step 194, objective = 1194.3423787757738
# Step 195, objective = 1214.342319923936
# Step 196, objective = 1185.2486272922536
# Step 197, objective = 1222.6571166055132
# Step 198, objective = 1172.3354741662129
# Step 199, objective = 1201.3249898782785
# Stopping criteria 'maxiter' met, end of optimization

# %%
z_nodes[design_nodes] = x_opt
zs_filtered = z_nodes.copy()
zs_filtered[design_nodes] =(B_ij@z_nodes)[design_nodes]

# %%
#Update the nodes
# %matplotlib inline

z_ele[:,0] = zs_filtered[cnct[:,0]]
z_ele[:,1] = zs_filtered[cnct[:,1]]

fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(projection='3d')
ax.set_zlim(0,20)
ax.set_xlabel('X (m)',fontsize=15)
ax.set_ylabel('Y (m)',fontsize=15)
ax.set_zlabel('Z (m)',fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
#Plot a basic wireframe.
for i in range(n_ele):
  ax.plot([x_ele[i,0],x_ele[i,1]],[y_ele[i,0],y_ele[i,1]],[z_ele[i,0],z_ele[i,1]],color='darkcyan')

ax.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],z_nodes[non_design_nodes],color='black',label='Non-design nodes')
ax.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],z_nodes[non_design_nodes]-0.2,s=150,marker='^',alpha=0.2,color='black')
ax.view_init(5, 90)
plt.legend(fontsize=17, loc=(0.5,0.7))
ax.grid(False)
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))
plt.show()

# %%
z_nodes=zs_filtered

# %%
################
#  SSO MODEL   #
################
#Build the model
#Sectional properties-> 600x400 rectangle

model = Model.Model() #model for sensitivity analysis

#Adding nodes and boundary conditions
for i in range(n_node):

    model.add_node(i,x_nodes[i],y_nodes[i],z_nodes[i])
    if i not in design_nodes:
        model.add_support(i,[1,1,1,1,0,1]) #Pinned, only Ry allow
    else:
        model.add_nodal_load(i,nodal_load=[0.0,0.0,-load,0.0,0.0,0.0])

#Adding elements
for i in range(n_ele):
    i_node = cnct[i,0]
    j_node = cnct[i,1]
    #ai
    a_i = 1e-10
    model.add_beamcol(i,i_node,j_node,E,G,a_i*Iy,a_i*Iz,J,A) 
model.model_ready()
model.solve()
print(model.strain_energy())
# Out:
# 1163.0573849259274

# %%
np.max(np.abs(model.u[design_nodes*6+2]))
# Out:
# 0.057245209125551644

# %%
fig, ax = plt.subplots(figsize=(5,5))

plt.plot(np.linspace(0,np.array(C_hist).shape[0],np.array(C_hist).shape[0]),np.array(C_hist)/1000,linewidth=2)
plt.xticks(np.linspace(0,np.array(C_hist).shape[0],5),fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Iteration',fontsize=16)
plt.title('Optimization history',fontsize=16)
plt.ylabel(r'Total strain energy (KN$\cdot$m)',fontsize=16)
# Out:
# Text(0, 0.5, 'Total strain energy (KN$\\cdot$m)')

# %%
# Start the SSO model
sso_model = SSO_model(model) # initial sso model
ele_Length = [] #calculate the length of every member
for eletag in range(n_ele):
    eleparameter = ElementParameter(eletag,ele_type = 0,prop_type = 5) # element object
    sso_model.add_eleparameter(eleparameter)
    
    node_1 = np.array([x_ele[eletag,0],y_ele[eletag,0],z_ele[eletag,0]])
    node_2 = np.array([x_ele[eletag,1],y_ele[eletag,1],z_ele[eletag,1]])
    temp_length = np.linalg.norm(node_1-node_2)
    ele_Length.append(temp_length)

#Initial the parameters
sso_model.initialize_parameters_values()
ele_Length = np.array(ele_Length)

# %%
#W(A): total volume
def volume(A):
    '''
    Volume and penalty
    '''
    
    return ele_Length.T@A + 0.05*penalty(A)
def penalty(A):
    '''
    Limit the minimum area
    '''
    threshold = np.pi*(d/4)**2/4
    return jnp.sum(jnp.where(A<threshold,((threshold-A)/threshold),0))
    
#C(A): violation of displacement
def user_obj(sso_model,u,u_max):
    u_z = jnp.abs(u[design_nodes*6+2]) #Z-displacement
    n_uz = u_z/u_max-1 #normalize
    c = jnp.sum(jnp.where(n_uz>0,n_uz,0))
    return c
sso_model.set_objective(objective='user',func=user_obj,func_args=(0.8,))

# %%
volume(sso_model.parameter_values)
# Out:
# Array(22.21459381, dtype=float64)

# %%
penalty(sso_model.parameter_values)
# Out:
# Array(0., dtype=float64)

# %%
sso_model.params_to_objective()
# Out:
# Array(0., dtype=float64)

# %%
sso_model.value_grad_params()[1]
# Out:
# Array([0., 0., 0., ..., 0., 0., 0.], dtype=float64)

# %%
eps1 = 1
eps2 = 1
i = 0
W_list = []#Storing the total weight
SE_list = []#Storing the strain energy
u_max_list = []#Storing the maximum displacement along Z

# %%
def objective(A,sso_model=sso_model):
    sso_model.update_eleparameter(A) # Update the model
    c,grad_c = sso_model.value_grad_params(which_solver='sparse',enforce_scipy_sparse = True)
    W,grad_W = value_and_grad(volume)(sso_model.parameter_values) #Volume/weight
    pen = penalty(sso_model.parameter_values) #Volume/weight
    W_list.append(W)
    SE_list.append(sso_model.params_c(sso_model.parameter_values,which_solver='sparse',enforce_scipy_sparse = True))
    u_max = np.max(np.abs(sso_model.params_u(sso_model.parameter_values,which_solver='sparse',enforce_scipy_sparse = True))[design_nodes*6+2])
    u_max_list.append(u_max)
    #p,grad_p = 
    kappa = 1+0.015#1/n_node #learning parameter of eps1
    global i,eps1
    if c>0 or pen>0:
        eps1 = (1/kappa)*eps1
    else:
        eps1 = (kappa)*eps1
    print('Displacement violation:',c,'  Area penalty',pen,' Volome and penalty',W)
    i+=1
    obj = (1+eps1*c)**eps2 * W 
    
    sens = eps2*(1+eps1*c)**(eps2-1)*grad_c*W + (1+eps1*c)**(eps2)*grad_W
    return obj,sens #sens_params

# %%
n_A = sso_model.parameter_values.shape[0] #number of parameters
A_ini = sso_model.parameter_values #initial parameters 
opt = optimization.Optimization(n_A,method='GD')
opt.set_objective(objective) #objective function
opt.set_maxiter(1000) #max iteration
opt.set_step_size(5e-4) #step size
opt.set_GD_normalized(True) #normalized
A_opt = opt.optimize(A_ini,log=True)
# Out:
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 22.214593812327085
# Step 0, objective = 22.214593812327085
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 21.489218372941306
# Step 1, objective = 21.489218372941306
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 20.763842933555527
# Step 2, objective = 20.763842933555527
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 20.038467494169748
# Step 3, objective = 20.038467494169748
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 19.313092054783972
# Step 4, objective = 19.313092054783972
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 18.58771661539819
# Step 5, objective = 18.58771661539819
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 17.862341176012414
# Step 6, objective = 17.862341176012414
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 17.136965736626635
# Step 7, objective = 17.136965736626635
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 16.411590297240856
# Step 8, objective = 16.411590297240856
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 15.686214857855077
# Step 9, objective = 15.686214857855077
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 14.960839418469298
# Step 10, objective = 14.960839418469298
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 14.23546397908352
# Step 11, objective = 14.23546397908352
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 13.51008853969774
# Step 12, objective = 13.51008853969774
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 12.784713100311963
# Step 13, objective = 12.784713100311963
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 12.059337660926184
# Step 14, objective = 12.059337660926184
# Displacement violation: 0.0   Area penalty 1.2979020381677056  Volome and penalty 11.398857323448793
# Step 15, objective = 11.398857323448793
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 11.326612636867967
# Step 16, objective = 11.326612636867967
# Displacement violation: 0.0   Area penalty 4.738863503346886  Volome and penalty 10.838180372649534
# Step 17, objective = 10.838180372649534
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 10.600615843609816
# Step 18, objective = 10.600615843609816
# Displacement violation: 0.0   Area penalty 6.75496220320735  Volome and penalty 10.212988514384406
# Step 19, objective = 10.212988514384406
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 9.877814759429082
# Step 20, objective = 9.877814759429082
# Displacement violation: 0.0   Area penalty 13.573743472080814  Volome and penalty 9.831126493647348
# Step 21, objective = 9.831126493647348
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 9.163659909183256
# Step 22, objective = 9.163659909183256
# Displacement violation: 0.0   Area penalty 14.983037800407311  Volome and penalty 9.187436359817845
# Step 23, objective = 9.187436359817845
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 8.458283841307361
# Step 24, objective = 8.458283841307361
# Displacement violation: 0.0   Area penalty 19.372566777015845  Volome and penalty 8.701536740772376
# Step 25, objective = 8.701536740772376
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 7.760737856139049
# Step 26, objective = 7.760737856139049
# Displacement violation: 0.0   Area penalty 22.735508886864928  Volome and penalty 8.172137861096518
# Step 27, objective = 8.172137861096518
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 7.067751959519985
# Step 28, objective = 7.067751959519985
# Displacement violation: 0.0   Area penalty 32.411476299936545  Volome and penalty 7.962950335131033
# Step 29, objective = 7.962950335131033
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 6.396261169848609
# Step 30, objective = 6.396261169848609
# Displacement violation: 0.0   Area penalty 42.64670455101422  Volome and penalty 7.803220958013541
# Step 31, objective = 7.803220958013541
# Displacement violation: 0.0   Area penalty 0.0417575533708957  Volome and penalty 5.742236329884889
# Step 32, objective = 5.742236329884889
# Displacement violation: 0.0   Area penalty 0.009768582236615772  Volome and penalty 5.73315047707856
# Step 33, objective = 5.73315047707856
# Displacement violation: 0.0   Area penalty 0.007389480199337766  Volome and penalty 5.72101020095852
# Step 34, objective = 5.72101020095852
# Displacement violation: 0.0   Area penalty 0.017716052251026973  Volome and penalty 5.709593399752268
# Step 35, objective = 5.709593399752268
# Displacement violation: 0.0   Area penalty 0.005834377538088556  Volome and penalty 5.698283337965979
# Step 36, objective = 5.698283337965979
# Displacement violation: 0.0   Area penalty 0.03909120173214769  Volome and penalty 5.689151392005568
# Step 37, objective = 5.689151392005568
# Displacement violation: 0.0   Area penalty 0.0  Volome and penalty 5.6770776441567
# Step 38, objective = 5.6770776441567
# Displacement violation: 0.29424104940157547   Area penalty 93.41174509230088  Volome and penalty 9.622289459385964
# Step 39, objective = 12.811696995536403
# Displacement violation: 0.0   Area penalty 91.30366079543806  Volome and penalty 9.518806495809201
# Step 40, objective = 9.518806495809201
# Displacement violation: 0.0   Area penalty 0.07087949382127216  Volome and penalty 5.113297356735091
# Step 41, objective = 5.113297356735091
# Displacement violation: 0.0   Area penalty 0.006012804585761105  Volome and penalty 5.102741654446908
# Step 42, objective = 5.102741654446908
# Displacement violation: 0.0   Area penalty 0.07647170045271326  Volome and penalty 5.095976115982067
# Step 43, objective = 5.095976115982067
# Displacement violation: 0.0   Area penalty 0.026724476301920465  Volome and penalty 5.087128687366306
# Step 44, objective = 5.087128687366306
# Displacement violation: 0.0   Area penalty 0.05414491615631552  Volome and penalty 5.079777226027945
# Step 45, objective = 5.079777226027945
# Displacement violation: 0.0   Area penalty 0.04597813784329474  Volome and penalty 5.072705993806356
# Step 46, objective = 5.072705993806356
# Displacement violation: 0.0   Area penalty 0.033835683370706165  Volome and penalty 5.064860993116191
# Step 47, objective = 5.064860993116191
# Displacement violation: 0.0   Area penalty 0.008606190647456246  Volome and penalty 5.0548308844813405
# Step 48, objective = 5.0548308844813405
# Displacement violation: 0.0   Area penalty 0.046009524218021056  Volome and penalty 5.045763765691233
# Step 49, objective = 5.045763765691233
# Displacement violation: 0.0   Area penalty 0.0075561763299582295  Volome and penalty 5.034571690190516
# Step 50, objective = 5.034571690190516
# Displacement violation: 0.0   Area penalty 0.0442917067247711  Volome and penalty 5.0243662022570685
# Step 51, objective = 5.0243662022570685
# Displacement violation: 0.0   Area penalty 0.018547147542022517  Volome and penalty 5.014228810566887
# Step 52, objective = 5.014228810566887
# Displacement violation: 0.0   Area penalty 0.04242191011438406  Volome and penalty 5.003909983297179
# Step 53, objective = 5.003909983297179
# Displacement violation: 0.0   Area penalty 0.021108486833458978  Volome and penalty 4.99611146092513
# Step 54, objective = 4.99611146092513
# Displacement violation: 0.0   Area penalty 0.0370089035145075  Volome and penalty 4.986984917939317
# Step 55, objective = 4.986984917939317
# Displacement violation: 0.0   Area penalty 0.04005443380960202  Volome and penalty 4.978420711859441
# Step 56, objective = 4.978420711859441
# Displacement violation: 0.0   Area penalty 0.08741830866525024  Volome and penalty 4.973659220376372
# Step 57, objective = 4.973659220376372
# Displacement violation: 0.0   Area penalty 0.0977137631896816  Volome and penalty 4.973325986927672
# Step 58, objective = 4.973325986927672
# Displacement violation: 0.0   Area penalty 0.07453993637382922  Volome and penalty 4.9692452797038005
# Step 59, objective = 4.9692452797038005
# Displacement violation: 0.0   Area penalty 0.05760609525368954  Volome and penalty 4.965123075718583
# Step 60, objective = 4.965123075718583
# Displacement violation: 0.0   Area penalty 0.1892203733001271  Volome and penalty 4.966997266991597
# Step 61, objective = 4.966997266991597
# Displacement violation: 0.0   Area penalty 0.061242707782696956  Volome and penalty 4.964246594458889
# Step 62, objective = 4.964246594458889
# Displacement violation: 0.0   Area penalty 0.03255738710843582  Volome and penalty 4.955625236773366
# Step 63, objective = 4.955625236773366
# Displacement violation: 0.0   Area penalty 0.05967463594306863  Volome and penalty 4.947643934034834
# Step 64, objective = 4.947643934034834
# Displacement violation: 0.0   Area penalty 0.14052802571561193  Volome and penalty 4.944511229788857
# Step 65, objective = 4.944511229788857
# Displacement violation: 0.0   Area penalty 0.07072177438320815  Volome and penalty 4.943338516852624
# Step 66, objective = 4.943338516852624
# Displacement violation: 0.0   Area penalty 0.08702890142077055  Volome and penalty 4.939546272138393
# Step 67, objective = 4.939546272138393
# Displacement violation: 0.0   Area penalty 0.11356388570746681  Volome and penalty 4.938564599069249
# Step 68, objective = 4.938564599069249
# Displacement violation: 0.0   Area penalty 0.0806470494392325  Volome and penalty 4.935324935192328
# Step 69, objective = 4.935324935192328
# Displacement violation: 0.0   Area penalty 0.0198117037744148  Volome and penalty 4.92887366831464
# Step 70, objective = 4.92887366831464
# Displacement violation: 0.0   Area penalty 0.07171235640303468  Volome and penalty 4.9215185320036525
# Step 71, objective = 4.9215185320036525
# Displacement violation: 0.0   Area penalty 0.1667372190330499  Volome and penalty 4.921962546450258
# Step 72, objective = 4.921962546450258
# Displacement violation: 0.0   Area penalty 0.2854291661099601  Volome and penalty 4.935760970136656
# Step 73, objective = 4.935760970136656
# Displacement violation: 0.0   Area penalty 0.032057133437126066  Volome and penalty 4.9361854408242865
# Step 74, objective = 4.9361854408242865
# Displacement violation: 0.0   Area penalty 0.09211110183962205  Volome and penalty 4.930042247608807
# Step 75, objective = 4.930042247608807
# Displacement violation: 0.0   Area penalty 0.050376356780533704  Volome and penalty 4.927008025654494
# Step 76, objective = 4.927008025654494
# Displacement violation: 0.0   Area penalty 0.055126146563786504  Volome and penalty 4.91950070763632
# Step 77, objective = 4.91950070763632
# Displacement violation: 0.0   Area penalty 0.05967786878350395  Volome and penalty 4.911800058295943
# Step 78, objective = 4.911800058295943
# Displacement violation: 0.0   Area penalty 0.03204737406025267  Volome and penalty 4.904108932829398
# Step 79, objective = 4.904108932829398
# Displacement violation: 0.0   Area penalty 0.07203998207903037  Volome and penalty 4.8977898452889885
# Step 80, objective = 4.8977898452889885
# Displacement violation: 0.0   Area penalty 0.012733174120805844  Volome and penalty 4.887751695277275
# Step 81, objective = 4.887751695277275
# Displacement violation: 0.0   Area penalty 0.03919563868540458  Volome and penalty 4.8796617641645295
# Step 82, objective = 4.8796617641645295
# Displacement violation: 0.0   Area penalty 0.07560688258681705  Volome and penalty 4.872695868697774
# Step 83, objective = 4.872695868697774
# Displacement violation: 0.0   Area penalty 0.04615184888557054  Volome and penalty 4.8689390209146115
# Step 84, objective = 4.8689390209146115
# Displacement violation: 0.0   Area penalty 0.012828631599274123  Volome and penalty 4.860271126295805
# Step 85, objective = 4.860271126295805
# Displacement violation: 0.0   Area penalty 0.027882082332884316  Volome and penalty 4.8505985070383195
# Step 86, objective = 4.8505985070383195
# Displacement violation: 0.0   Area penalty 0.06927210222192465  Volome and penalty 4.84505686077465
# Step 87, objective = 4.84505686077465
# Displacement violation: 0.0   Area penalty 0.03511851031106962  Volome and penalty 4.8376957895440285
# Step 88, objective = 4.8376957895440285
# Displacement violation: 0.0   Area penalty 0.04240741422482046  Volome and penalty 4.828079224471503
# Step 89, objective = 4.828079224471503
# Displacement violation: 0.0   Area penalty 0.04016167311237062  Volome and penalty 4.819680923830953
# Step 90, objective = 4.819680923830953
# Displacement violation: 0.0   Area penalty 0.010651155591548571  Volome and penalty 4.808880697631158
# Step 91, objective = 4.808880697631158
# Displacement violation: 0.0   Area penalty 0.04243169341047029  Volome and penalty 4.799102495866122
# Step 92, objective = 4.799102495866122
# Displacement violation: 0.0   Area penalty 0.029182633641643616  Volome and penalty 4.790323179590257
# Step 93, objective = 4.790323179590257
# Displacement violation: 0.0   Area penalty 0.037924267272785  Volome and penalty 4.780841073141225
# Step 94, objective = 4.780841073141225
# Displacement violation: 0.0   Area penalty 0.09124204356352782  Volome and penalty 4.775098939755184
# Step 95, objective = 4.775098939755184
# Displacement violation: 0.0   Area penalty 0.05938269541779778  Volome and penalty 4.767674705092508
# Step 96, objective = 4.767674705092508
# Displacement violation: 0.0   Area penalty 0.04277975163920802  Volome and penalty 4.759533209540364
# Step 97, objective = 4.759533209540364
# Displacement violation: 0.0   Area penalty 0.046792329608140934  Volome and penalty 4.7503233713981246
# Step 98, objective = 4.7503233713981246
# Displacement violation: 0.0   Area penalty 0.030650024491851963  Volome and penalty 4.7427116697100855
# Step 99, objective = 4.7427116697100855
# Displacement violation: 0.0   Area penalty 0.05760216499632367  Volome and penalty 4.734166219913592
# Step 100, objective = 4.734166219913592
# Displacement violation: 0.0   Area penalty 0.0765490319018466  Volome and penalty 4.729061919748209
# Step 101, objective = 4.729061919748209
# Displacement violation: 0.0   Area penalty 0.17023087640787538  Volome and penalty 4.729196065780761
# Step 102, objective = 4.729196065780761
# Displacement violation: 0.0   Area penalty 0.04412393455955979  Volome and penalty 4.7209034786810005
# Step 103, objective = 4.7209034786810005
# Displacement violation: 0.0   Area penalty 0.07683257863889542  Volome and penalty 4.716579305256338
# Step 104, objective = 4.716579305256338
# Displacement violation: 0.0   Area penalty 0.07366424913688215  Volome and penalty 4.712399068384668
# Step 105, objective = 4.712399068384668
# Displacement violation: 0.0   Area penalty 0.029273679993838564  Volome and penalty 4.705025648609912
# Step 106, objective = 4.705025648609912
# Displacement violation: 0.0   Area penalty 0.021778889216310264  Volome and penalty 4.695396955726102
# Step 107, objective = 4.695396955726102
# Displacement violation: 0.0   Area penalty 0.030118334103701516  Volome and penalty 4.686521719322895
# Step 108, objective = 4.686521719322895
# Displacement violation: 0.0   Area penalty 0.018555371688748237  Volome and penalty 4.675586595253462
# Step 109, objective = 4.675586595253462
# Displacement violation: 0.0   Area penalty 0.026016246579308396  Volome and penalty 4.66557237463464
# Step 110, objective = 4.66557237463464
# Displacement violation: 0.0   Area penalty 0.02537901026448804  Volome and penalty 4.656102453735497
# Step 111, objective = 4.656102453735497
# Displacement violation: 0.0   Area penalty 0.0600438634483039  Volome and penalty 4.649080529200797
# Step 112, objective = 4.649080529200797
# Displacement violation: 0.0   Area penalty 0.1378887426931883  Volome and penalty 4.646184145285436
# Step 113, objective = 4.646184145285436
# Displacement violation: 0.0   Area penalty 0.1077855192471797  Volome and penalty 4.643050925288972
# Step 114, objective = 4.643050925288972
# Displacement violation: 0.0   Area penalty 0.07135317435354512  Volome and penalty 4.63857520600518
# Step 115, objective = 4.63857520600518
# Displacement violation: 0.0   Area penalty 0.08256907901601189  Volome and penalty 4.6331942463239395
# Step 116, objective = 4.6331942463239395
# Displacement violation: 0.0   Area penalty 0.050997112777383564  Volome and penalty 4.631084668794912
# Step 117, objective = 4.631084668794912
# Displacement violation: 0.0   Area penalty 0.09931918055803744  Volome and penalty 4.626464191902491
# Step 118, objective = 4.626464191902491
# Displacement violation: 0.0   Area penalty 0.0719538954348268  Volome and penalty 4.6229217456247955
# Step 119, objective = 4.6229217456247955
# Displacement violation: 0.0   Area penalty 0.04640006686892473  Volome and penalty 4.615108941664633
# Step 120, objective = 4.615108941664633
# Displacement violation: 0.0   Area penalty 0.07331376459535394  Volome and penalty 4.609072861357894
# Step 121, objective = 4.609072861357894
# Displacement violation: 0.0   Area penalty 0.11416817467608276  Volome and penalty 4.606262188368595
# Step 122, objective = 4.606262188368595
# Displacement violation: 0.0   Area penalty 0.045433790185376174  Volome and penalty 4.59903653814177
# Step 123, objective = 4.59903653814177
# Displacement violation: 0.0   Area penalty 0.03572395385853212  Volome and penalty 4.5937077096490375
# Step 124, objective = 4.5937077096490375
# Displacement violation: 0.0   Area penalty 0.13168714589116798  Volome and penalty 4.592245449113803
# Step 125, objective = 4.592245449113803
# Displacement violation: 0.0   Area penalty 0.14368554544799228  Volome and penalty 4.592678361493901
# Step 126, objective = 4.592678361493901
# Displacement violation: 0.0   Area penalty 0.24777882179138677  Volome and penalty 4.602787626457116
# Step 127, objective = 4.602787626457116
# Displacement violation: 0.0   Area penalty 0.1156804606137422  Volome and penalty 4.603946245561367
# Step 128, objective = 4.603946245561367
# Displacement violation: 0.0   Area penalty 0.05403652202973833  Volome and penalty 4.5989150359528015
# Step 129, objective = 4.5989150359528015
# Displacement violation: 0.0   Area penalty 0.051824681633128096  Volome and penalty 4.590041195311372
# Step 130, objective = 4.590041195311372
# Displacement violation: 0.0   Area penalty 0.03665081368412942  Volome and penalty 4.581255985486446
# Step 131, objective = 4.581255985486446
# Displacement violation: 0.0   Area penalty 0.07514769487018552  Volome and penalty 4.574073980476517
# Step 132, objective = 4.574073980476517
# Displacement violation: 0.0   Area penalty 0.059168070455210636  Volome and penalty 4.568542891856406
# Step 133, objective = 4.568542891856406
# Displacement violation: 0.0   Area penalty 0.13019244182072917  Volome and penalty 4.563514464380303
# Step 134, objective = 4.563514464380303
# Displacement violation: 0.0   Area penalty 0.01910653153079347  Volome and penalty 4.5559192252993626
# Step 135, objective = 4.5559192252993626
# Displacement violation: 0.0   Area penalty 0.018551440203739063  Volome and penalty 4.545461231746528
# Step 136, objective = 4.545461231746528
# Displacement violation: 0.0   Area penalty 0.08857201875953617  Volome and penalty 4.5374658356776
# Step 137, objective = 4.5374658356776
# Displacement violation: 0.0   Area penalty 0.010020551015775913  Volome and penalty 4.528536414939221
# Step 138, objective = 4.528536414939221
# Displacement violation: 0.0   Area penalty 0.03366678639185382  Volome and penalty 4.518350749250571
# Step 139, objective = 4.518350749250571
# Displacement violation: 0.0   Area penalty 0.01941736915787352  Volome and penalty 4.508409824012479
# Step 140, objective = 4.508409824012479
# Displacement violation: 0.0   Area penalty 0.039104661153549894  Volome and penalty 4.498958274084348
# Step 141, objective = 4.498958274084348
# Displacement violation: 0.0   Area penalty 0.05920807072439745  Volome and penalty 4.492471365714264
# Step 142, objective = 4.492471365714264
# Displacement violation: 0.0   Area penalty 0.07190464920556155  Volome and penalty 4.487091126238471
# Step 143, objective = 4.487091126238471
# Displacement violation: 0.0   Area penalty 0.059687822066726626  Volome and penalty 4.479395211455216
# Step 144, objective = 4.479395211455216
# Displacement violation: 0.0   Area penalty 0.02776172161654055  Volome and penalty 4.469302519191178
# Step 145, objective = 4.469302519191178
# Displacement violation: 0.0   Area penalty 0.04942353724331626  Volome and penalty 4.460953895167897
# Step 146, objective = 4.460953895167897
# Displacement violation: 0.0   Area penalty 0.04751800502224052  Volome and penalty 4.4538997167241545
# Step 147, objective = 4.4538997167241545
# Displacement violation: 0.0   Area penalty 0.08262630756233084  Volome and penalty 4.446822397347047
# Step 148, objective = 4.446822397347047
# Displacement violation: 0.0   Area penalty 0.054500941345878524  Volome and penalty 4.44061721177303
# Step 149, objective = 4.44061721177303
# Displacement violation: 0.0   Area penalty 0.062235223405562666  Volome and penalty 4.432302060545408
# Step 150, objective = 4.432302060545408
# Displacement violation: 0.0   Area penalty 0.02805832461364811  Volome and penalty 4.426111018935758
# Step 151, objective = 4.426111018935758
# Displacement violation: 0.0   Area penalty 0.028798102897582775  Volome and penalty 4.417424341740826
# Step 152, objective = 4.417424341740826
# Displacement violation: 0.0   Area penalty 0.07085084520550747  Volome and penalty 4.411628147877742
# Step 153, objective = 4.411628147877742
# Displacement violation: 0.0   Area penalty 0.07138553896236619  Volome and penalty 4.408074117390253
# Step 154, objective = 4.408074117390253
# Displacement violation: 0.0   Area penalty 0.10030966298386712  Volome and penalty 4.404859692099826
# Step 155, objective = 4.404859692099826
# Displacement violation: 0.0   Area penalty 0.06682907435636437  Volome and penalty 4.400141748680916
# Step 156, objective = 4.400141748680916
# Displacement violation: 0.0   Area penalty 0.07878323024812493  Volome and penalty 4.395177526204254
# Step 157, objective = 4.395177526204254
# Displacement violation: 0.0   Area penalty 0.10186111802896874  Volome and penalty 4.392660057718788
# Step 158, objective = 4.392660057718788
# Displacement violation: 0.0   Area penalty 0.0934272914445977  Volome and penalty 4.390758070597753
# Step 159, objective = 4.390758070597753
# Displacement violation: 0.0   Area penalty 0.10782230524615363  Volome and penalty 4.386925136741369
# Step 160, objective = 4.386925136741369
# Displacement violation: 0.0   Area penalty 0.05854543185131769  Volome and penalty 4.38017476321828
# Step 161, objective = 4.38017476321828
# Displacement violation: 0.0   Area penalty 0.06146427250221442  Volome and penalty 4.373361611796833
# Step 162, objective = 4.373361611796833
# Displacement violation: 0.0   Area penalty 0.07809082412748491  Volome and penalty 4.368249960577855
# Step 163, objective = 4.368249960577855
# Displacement violation: 0.0   Area penalty 0.05827564295615474  Volome and penalty 4.363109782231362
# Step 164, objective = 4.363109782231362
# Displacement violation: 0.0   Area penalty 0.03882911724462955  Volome and penalty 4.356310213091899
# Step 165, objective = 4.356310213091899
# Displacement violation: 0.0   Area penalty 0.0725488046969611  Volome and penalty 4.3500924850248
# Step 166, objective = 4.3500924850248
# Displacement violation: 0.0   Area penalty 0.07179297211254684  Volome and penalty 4.344248879884455
# Step 167, objective = 4.344248879884455
# Displacement violation: 0.0   Area penalty 0.047355376063373325  Volome and penalty 4.337419161710138
# Step 168, objective = 4.337419161710138
# Displacement violation: 0.0   Area penalty 0.11023002006637928  Volome and penalty 4.332503728876596
# Step 169, objective = 4.332503728876596
# Displacement violation: 0.0   Area penalty 0.12074004055725673  Volome and penalty 4.331670147676904
# Step 170, objective = 4.331670147676904
# Displacement violation: 0.0   Area penalty 0.28973260774015536  Volome and penalty 4.344586639115801
# Step 171, objective = 4.344586639115801
# Displacement violation: 0.0   Area penalty 0.06506602032452932  Volome and penalty 4.352413028463825
# Step 172, objective = 4.352413028463825
# Displacement violation: 0.0   Area penalty 0.029734009355480946  Volome and penalty 4.343476368340997
# Step 173, objective = 4.343476368340997
# Displacement violation: 0.0   Area penalty 0.026767087194237024  Volome and penalty 4.334415929124415
# Step 174, objective = 4.334415929124415
# Displacement violation: 0.0   Area penalty 0.07019692068238292  Volome and penalty 4.327217669098497
# Step 175, objective = 4.327217669098497
# Displacement violation: 0.0   Area penalty 0.032261156671233436  Volome and penalty 4.319320471818341
# Step 176, objective = 4.319320471818341
# Displacement violation: 0.0   Area penalty 0.055496855929611434  Volome and penalty 4.3122877806092665
# Step 177, objective = 4.3122877806092665
# Displacement violation: 0.0   Area penalty 0.02813941755444459  Volome and penalty 4.3027223721167625
# Step 178, objective = 4.3027223721167625
# Displacement violation: 0.0   Area penalty 0.04721859093937171  Volome and penalty 4.294437758531269
# Step 179, objective = 4.294437758531269
# Displacement violation: 0.0   Area penalty 0.05092156753866157  Volome and penalty 4.2857972162962685
# Step 180, objective = 4.2857972162962685
# Displacement violation: 0.0   Area penalty 0.036908172150828686  Volome and penalty 4.279207164201369
# Step 181, objective = 4.279207164201369
# Displacement violation: 0.0   Area penalty 0.04912320198268405  Volome and penalty 4.27063887755074
# Step 182, objective = 4.27063887755074
# Displacement violation: 0.0   Area penalty 0.024044960178342466  Volome and penalty 4.26253209479008
# Step 183, objective = 4.26253209479008
# Displacement violation: 0.0   Area penalty 0.028440264455246826  Volome and penalty 4.25223142575931
# Step 184, objective = 4.25223142575931
# Displacement violation: 0.0   Area penalty 0.045535796209063596  Volome and penalty 4.243277300026081
# Step 185, objective = 4.243277300026081
# Displacement violation: 0.0   Area penalty 0.0893457693577433  Volome and penalty 4.238808818468654
# Step 186, objective = 4.238808818468654
# Displacement violation: 0.0   Area penalty 0.048666015509233704  Volome and penalty 4.232653443008594
# Step 187, objective = 4.232653443008594
# Displacement violation: 0.0   Area penalty 0.08559471471795976  Volome and penalty 4.226597608875765
# Step 188, objective = 4.226597608875765
# Displacement violation: 0.0   Area penalty 0.10977600452289654  Volome and penalty 4.222809220209337
# Step 189, objective = 4.222809220209337
# Displacement violation: 0.0   Area penalty 0.044354807058905835  Volome and penalty 4.21775396367224
# Step 190, objective = 4.21775396367224
# Displacement violation: 0.0   Area penalty 0.0393711547853204  Volome and penalty 4.208608653202851
# Step 191, objective = 4.208608653202851
# Displacement violation: 0.0   Area penalty 0.057791777012454144  Volome and penalty 4.2008813977756265
# Step 192, objective = 4.2008813977756265
# Displacement violation: 0.0   Area penalty 0.02709700135004941  Volome and penalty 4.193105007995203
# Step 193, objective = 4.193105007995203
# Displacement violation: 0.0   Area penalty 0.040120570327853614  Volome and penalty 4.18383266166669
# Step 194, objective = 4.18383266166669
# Displacement violation: 0.0   Area penalty 0.09816798143309705  Volome and penalty 4.183032750975919
# Step 195, objective = 4.183032750975919
# Displacement violation: 0.0   Area penalty 0.1113418408643494  Volome and penalty 4.180818882710485
# Step 196, objective = 4.180818882710485
# Displacement violation: 0.0   Area penalty 0.05539712840442804  Volome and penalty 4.177813700338618
# Step 197, objective = 4.177813700338618
# Displacement violation: 0.0   Area penalty 0.07867532725920146  Volome and penalty 4.175064400959138
# Step 198, objective = 4.175064400959138
# Displacement violation: 0.0   Area penalty 0.06121321505633966  Volome and penalty 4.170370872795617
# Step 199, objective = 4.170370872795617
# Displacement violation: 0.0   Area penalty 0.06569493212359825  Volome and penalty 4.1642000207957315
# Step 200, objective = 4.1642000207957315
# Displacement violation: 0.0   Area penalty 0.06879009062388958  Volome and penalty 4.158600580779946
# Step 201, objective = 4.158600580779946
# Displacement violation: 0.0   Area penalty 0.16480131867058678  Volome and penalty 4.157272806462877
# Step 202, objective = 4.157272806462877
# Displacement violation: 0.0   Area penalty 0.04904185078084544  Volome and penalty 4.150488211597698
# Step 203, objective = 4.150488211597698
# Displacement violation: 0.0   Area penalty 0.06210450293646451  Volome and penalty 4.144184382337328
# Step 204, objective = 4.144184382337328
# Displacement violation: 0.0   Area penalty 0.06163060623613522  Volome and penalty 4.138093478086425
# Step 205, objective = 4.138093478086425
# Displacement violation: 0.0   Area penalty 0.05696922351631828  Volome and penalty 4.132399113480702
# Step 206, objective = 4.132399113480702
# Displacement violation: 0.0   Area penalty 0.04518603174715414  Volome and penalty 4.124330910862644
# Step 207, objective = 4.124330910862644
# Displacement violation: 0.0   Area penalty 0.07152180593188241  Volome and penalty 4.11637748872099
# Step 208, objective = 4.11637748872099
# Displacement violation: 0.0   Area penalty 0.0579445782924546  Volome and penalty 4.109217076426415
# Step 209, objective = 4.109217076426415
# Displacement violation: 0.0   Area penalty 0.0401916238113458  Volome and penalty 4.101679746650879
# Step 210, objective = 4.101679746650879
# Displacement violation: 0.0   Area penalty 0.05437550261060814  Volome and penalty 4.093628641585132
# Step 211, objective = 4.093628641585132
# Displacement violation: 0.0   Area penalty 0.06360645601838008  Volome and penalty 4.087428631371624
# Step 212, objective = 4.087428631371624
# Displacement violation: 0.0   Area penalty 0.0695740536461333  Volome and penalty 4.083101466208263
# Step 213, objective = 4.083101466208263
# Displacement violation: 0.0   Area penalty 0.09747202380500676  Volome and penalty 4.083185455164482
# Step 214, objective = 4.083185455164482
# Displacement violation: 0.0   Area penalty 0.12385585854465891  Volome and penalty 4.081909687314288
# Step 215, objective = 4.081909687314288
# Displacement violation: 0.0   Area penalty 0.08153976593189446  Volome and penalty 4.080423004980643
# Step 216, objective = 4.080423004980643
# Displacement violation: 0.0   Area penalty 0.09027476458828806  Volome and penalty 4.0791363301760315
# Step 217, objective = 4.0791363301760315
# Displacement violation: 0.0   Area penalty 0.1333814965456109  Volome and penalty 4.0782987698974225
# Step 218, objective = 4.0782987698974225
# Displacement violation: 0.0   Area penalty 0.08633317263929727  Volome and penalty 4.072818843640388
# Step 219, objective = 4.072818843640388
# Displacement violation: 0.0   Area penalty 0.07635285640749855  Volome and penalty 4.071097695808982
# Step 220, objective = 4.071097695808982
# Displacement violation: 0.0   Area penalty 0.0522880285825185  Volome and penalty 4.065688449858591
# Step 221, objective = 4.065688449858591
# Displacement violation: 0.0   Area penalty 0.08763638933786237  Volome and penalty 4.060222029659298
# Step 222, objective = 4.060222029659298
# Displacement violation: 0.0   Area penalty 0.11053100894378193  Volome and penalty 4.059407223045896
# Step 223, objective = 4.059407223045896
# Displacement violation: 0.0   Area penalty 0.12512773348268233  Volome and penalty 4.05999651021137
# Step 224, objective = 4.05999651021137
# Displacement violation: 0.0   Area penalty 0.10105581820800515  Volome and penalty 4.056136101698981
# Step 225, objective = 4.056136101698981
# Displacement violation: 0.0   Area penalty 0.0548132452653367  Volome and penalty 4.051275641534197
# Step 226, objective = 4.051275641534197
# Displacement violation: 0.0   Area penalty 0.08703096351850036  Volome and penalty 4.048406370514635
# Step 227, objective = 4.048406370514635
# Displacement violation: 0.0   Area penalty 0.14822043159777476  Volome and penalty 4.048055845382332
# Step 228, objective = 4.048055845382332
# Displacement violation: 0.0   Area penalty 0.15754517415564842  Volome and penalty 4.052333245085339
# Step 229, objective = 4.052333245085339
# Displacement violation: 0.0   Area penalty 0.10046135823656901  Volome and penalty 4.052302002232443
# Step 230, objective = 4.052302002232443
# Displacement violation: 0.0   Area penalty 0.11992010471640313  Volome and penalty 4.04900271057576
# Step 231, objective = 4.04900271057576
# Displacement violation: 0.0   Area penalty 0.03311567152654134  Volome and penalty 4.040533463773494
# Step 232, objective = 4.040533463773494
# Displacement violation: 0.0   Area penalty 0.024110597378631464  Volome and penalty 4.032438888782369
# Step 233, objective = 4.032438888782369
# Displacement violation: 0.0   Area penalty 0.08858537442682723  Volome and penalty 4.02603724747542
# Step 234, objective = 4.02603724747542
# Displacement violation: 0.0   Area penalty 0.0458308518536354  Volome and penalty 4.018405039716754
# Step 235, objective = 4.018405039716754
# Displacement violation: 0.0   Area penalty 0.06273667575791991  Volome and penalty 4.010578970488086
# Step 236, objective = 4.010578970488086
# Displacement violation: 0.0   Area penalty 0.04775671540332387  Volome and penalty 4.003860451957536
# Step 237, objective = 4.003860451957536
# Displacement violation: 0.0   Area penalty 0.045374418586263794  Volome and penalty 3.9970807605604404
# Step 238, objective = 3.9970807605604404
# Displacement violation: 0.0   Area penalty 0.13609829157453393  Volome and penalty 3.995426167624197
# Step 239, objective = 3.995426167624197
# Displacement violation: 0.0   Area penalty 0.09261691192317109  Volome and penalty 3.9947153081911577
# Step 240, objective = 3.9947153081911577
# Displacement violation: 0.0   Area penalty 0.066331716153658  Volome and penalty 3.9897591656980813
# Step 241, objective = 3.9897591656980813
# Displacement violation: 0.0   Area penalty 0.07508226530908126  Volome and penalty 3.9828633267566294
# Step 242, objective = 3.9828633267566294
# Displacement violation: 0.0   Area penalty 0.0595248694757707  Volome and penalty 3.976652920488085
# Step 243, objective = 3.976652920488085
# Displacement violation: 0.0   Area penalty 0.02701004339905605  Volome and penalty 3.968615150794577
# Step 244, objective = 3.968615150794577
# Displacement violation: 0.0   Area penalty 0.03605539519232618  Volome and penalty 3.9607283220874456
# Step 245, objective = 3.9607283220874456
# Displacement violation: 0.0   Area penalty 0.02061945257372976  Volome and penalty 3.951050068804632
# Step 246, objective = 3.951050068804632
# Displacement violation: 0.0   Area penalty 0.10867092144644547  Volome and penalty 3.94811991926255
# Step 247, objective = 3.94811991926255
# Displacement violation: 0.0   Area penalty 0.07707466073920749  Volome and penalty 3.9465022274792774
# Step 248, objective = 3.9465022274792774
# Displacement violation: 0.0   Area penalty 0.057569241747803715  Volome and penalty 3.9414192938737465
# Step 249, objective = 3.9414192938737465
# Displacement violation: 0.0   Area penalty 0.042488949292350274  Volome and penalty 3.936119802822457
# Step 250, objective = 3.936119802822457
# Displacement violation: 0.0   Area penalty 0.08979587527607927  Volome and penalty 3.934237380902128
# Step 251, objective = 3.934237380902128
# Displacement violation: 0.0   Area penalty 0.16252438686539267  Volome and penalty 3.938605098449005
# Step 252, objective = 3.938605098449005
# Displacement violation: 0.0   Area penalty 0.07202883646584154  Volome and penalty 3.9362475840850992
# Step 253, objective = 3.9362475840850992
# Displacement violation: 0.0   Area penalty 0.0789983997384618  Volome and penalty 3.929354073061838
# Step 254, objective = 3.929354073061838
# Displacement violation: 0.0   Area penalty 0.06139893916668504  Volome and penalty 3.922621816875533
# Step 255, objective = 3.922621816875533
# Displacement violation: 0.0   Area penalty 0.12859791643586307  Volome and penalty 3.9227949766114825
# Step 256, objective = 3.9227949766114825
# Displacement violation: 0.0   Area penalty 0.07370781194327536  Volome and penalty 3.921656136110238
# Step 257, objective = 3.921656136110238
# Displacement violation: 0.0   Area penalty 0.08244019770279909  Volome and penalty 3.9186719560974526
# Step 258, objective = 3.9186719560974526
# Displacement violation: 0.0   Area penalty 0.0700738306359832  Volome and penalty 3.9133397633388487
# Step 259, objective = 3.9133397633388487
# Displacement violation: 0.0   Area penalty 0.10288603355563217  Volome and penalty 3.910973243400464
# Step 260, objective = 3.910973243400464
# Displacement violation: 0.0   Area penalty 0.14164843683972794  Volome and penalty 3.9113611702937487
# Step 261, objective = 3.9113611702937487
# Displacement violation: 0.0   Area penalty 0.10872126287718228  Volome and penalty 3.9122053424669363
# Step 262, objective = 3.9122053424669363
# Displacement violation: 0.0   Area penalty 0.08492569829949012  Volome and penalty 3.9083024272949842
# Step 263, objective = 3.9083024272949842
# Displacement violation: 0.0   Area penalty 0.12647563728320502  Volome and penalty 3.9061621918445266
# Step 264, objective = 3.9061621918445266
# Displacement violation: 0.0   Area penalty 0.1456508692949712  Volome and penalty 3.9060297705716955
# Step 265, objective = 3.9060297705716955
# Displacement violation: 0.0   Area penalty 0.05231176334136445  Volome and penalty 3.902521607356579
# Step 266, objective = 3.902521607356579
# Displacement violation: 0.0   Area penalty 0.10108157885996516  Volome and penalty 3.8976276879325953
# Step 267, objective = 3.8976276879325953
# Displacement violation: 0.0   Area penalty 0.107440294775595  Volome and penalty 3.899423450234166
# Step 268, objective = 3.899423450234166
# Displacement violation: 0.0   Area penalty 0.25879210153718607  Volome and penalty 3.9085365867666875
# Step 269, objective = 3.9085365867666875
# Displacement violation: 0.0   Area penalty 0.2628753445890657  Volome and penalty 3.92287161262246
# Step 270, objective = 3.92287161262246
# Displacement violation: 0.0   Area penalty 0.110820768689162  Volome and penalty 3.9237923709114697
# Step 271, objective = 3.9237923709114697
# Displacement violation: 0.0   Area penalty 0.14679207632467248  Volome and penalty 3.9266242586261253
# Step 272, objective = 3.9266242586261253
# Displacement violation: 0.0   Area penalty 0.11927303332998393  Volome and penalty 3.9251664729961457
# Step 273, objective = 3.9251664729961457
# Displacement violation: 0.0   Area penalty 0.07307446897333371  Volome and penalty 3.9202030145751805
# Step 274, objective = 3.9202030145751805
# Displacement violation: 0.0   Area penalty 0.07374807845234713  Volome and penalty 3.9158551037699536
# Step 275, objective = 3.9158551037699536
# Displacement violation: 0.0   Area penalty 0.07769525253004597  Volome and penalty 3.910748377879927
# Step 276, objective = 3.910748377879927
# Displacement violation: 0.0   Area penalty 0.06428269617732381  Volome and penalty 3.9040419075004746
# Step 277, objective = 3.9040419075004746
# Displacement violation: 0.0   Area penalty 0.10335321930617247  Volome and penalty 3.899672629299535
# Step 278, objective = 3.899672629299535
# Displacement violation: 0.0   Area penalty 0.06582776693591072  Volome and penalty 3.896879594890715
# Step 279, objective = 3.896879594890715
# Displacement violation: 0.0   Area penalty 0.12309409157269044  Volome and penalty 3.8941829111653434
# Step 280, objective = 3.8941829111653434
# Displacement violation: 0.0   Area penalty 0.09825172530773688  Volome and penalty 3.889900548607001
# Step 281, objective = 3.889900548607001
# Displacement violation: 0.0   Area penalty 0.045115557765995025  Volome and penalty 3.885092133866291
# Step 282, objective = 3.885092133866291
# Displacement violation: 0.0   Area penalty 0.06792669490589076  Volome and penalty 3.8790718812025147
# Step 283, objective = 3.8790718812025147
# Displacement violation: 0.0   Area penalty 0.06755303853702903  Volome and penalty 3.8742778173113486
# Step 284, objective = 3.8742778173113486
# Displacement violation: 0.0   Area penalty 0.1301684504279272  Volome and penalty 3.8743076826442846
# Step 285, objective = 3.8743076826442846
# Displacement violation: 0.0   Area penalty 0.10957410737879016  Volome and penalty 3.8733450896376977
# Step 286, objective = 3.8733450896376977
# Displacement violation: 0.0   Area penalty 0.09615963463266389  Volome and penalty 3.8711486437243963
# Step 287, objective = 3.8711486437243963
# Displacement violation: 0.0   Area penalty 0.09861449274123871  Volome and penalty 3.866103881707661
# Step 288, objective = 3.866103881707661
# Displacement violation: 0.0   Area penalty 0.12967369617945074  Volome and penalty 3.8655862393816545
# Step 289, objective = 3.8655862393816545
# Displacement violation: 0.0   Area penalty 0.04472084155106528  Volome and penalty 3.858728621224018
# Step 290, objective = 3.858728621224018
# Displacement violation: 0.0   Area penalty 0.07887882281925751  Volome and penalty 3.8508062407610923
# Step 291, objective = 3.8508062407610923
# Displacement violation: 0.0   Area penalty 0.07460698565507189  Volome and penalty 3.8492988382435698
# Step 292, objective = 3.8492988382435698
# Displacement violation: 0.0   Area penalty 0.08858675457525916  Volome and penalty 3.8441661358394676
# Step 293, objective = 3.8441661358394676
# Displacement violation: 0.0   Area penalty 0.18812448737162407  Volome and penalty 3.8467610416089904
# Step 294, objective = 3.8467610416089904
# Displacement violation: 0.0   Area penalty 0.08353096721573364  Volome and penalty 3.8486976805204365
# Step 295, objective = 3.8486976805204365
# Displacement violation: 0.0   Area penalty 0.08553060383887925  Volome and penalty 3.8435307485679564
# Step 296, objective = 3.8435307485679564
# Displacement violation: 0.0   Area penalty 0.10652173331065273  Volome and penalty 3.841008542474092
# Step 297, objective = 3.841008542474092
# Displacement violation: 0.0   Area penalty 0.11330034957241766  Volome and penalty 3.8408873893175874
# Step 298, objective = 3.8408873893175874
# Displacement violation: 0.0   Area penalty 0.048898868931998046  Volome and penalty 3.838800478598639
# Step 299, objective = 3.838800478598639
# Displacement violation: 0.0   Area penalty 0.08820093879815055  Volome and penalty 3.8329746523769774
# Step 300, objective = 3.8329746523769774
# Displacement violation: 0.0   Area penalty 0.10000224905103941  Volome and penalty 3.8309976335897633
# Step 301, objective = 3.8309976335897633
# Displacement violation: 0.0   Area penalty 0.13416831328076279  Volome and penalty 3.8334430388373297
# Step 302, objective = 3.8334430388373297
# Displacement violation: 0.0   Area penalty 0.06205790053691447  Volome and penalty 3.8323661518079954
# Step 303, objective = 3.8323661518079954
# Displacement violation: 0.0   Area penalty 0.0748113497724327  Volome and penalty 3.8284482052309143
# Step 304, objective = 3.8284482052309143
# Displacement violation: 0.0   Area penalty 0.0836285707843332  Volome and penalty 3.822108714572794
# Step 305, objective = 3.822108714572794
# Displacement violation: 0.0   Area penalty 0.17387540703379592  Volome and penalty 3.8257617495720524
# Step 306, objective = 3.8257617495720524
# Displacement violation: 0.0   Area penalty 0.20953694199248163  Volome and penalty 3.831874515402766
# Step 307, objective = 3.831874515402766
# Displacement violation: 0.0   Area penalty 0.07564295888189036  Volome and penalty 3.828925553689664
# Step 308, objective = 3.828925553689664
# Displacement violation: 0.0   Area penalty 0.12034997971479704  Volome and penalty 3.8298297252095406
# Step 309, objective = 3.8298297252095406
# Displacement violation: 0.0   Area penalty 0.11431561166491683  Volome and penalty 3.831661069661862
# Step 310, objective = 3.831661069661862
# Displacement violation: 0.0   Area penalty 0.0988641598820197  Volome and penalty 3.8308148250611023
# Step 311, objective = 3.8308148250611023
# Displacement violation: 0.0   Area penalty 0.18444383607902132  Volome and penalty 3.837314017686941
# Step 312, objective = 3.837314017686941
# Displacement violation: 0.0   Area penalty 0.1887462483077645  Volome and penalty 3.8449349401577813
# Step 313, objective = 3.8449349401577813
# Displacement violation: 0.0   Area penalty 0.16256054128653882  Volome and penalty 3.8544132294932654
# Step 314, objective = 3.8544132294932654
# Displacement violation: 0.0   Area penalty 0.22038377483679467  Volome and penalty 3.864409038056689
# Step 315, objective = 3.864409038056689
# Displacement violation: 0.0   Area penalty 0.17789415162966687  Volome and penalty 3.8693283491897885
# Step 316, objective = 3.8693283491897885
# Displacement violation: 0.0   Area penalty 0.07800402419354949  Volome and penalty 3.869298215489944
# Step 317, objective = 3.869298215489944
# Displacement violation: 0.0   Area penalty 0.11192396234525798  Volome and penalty 3.8666002583260584
# Step 318, objective = 3.8666002583260584
# Displacement violation: 0.0   Area penalty 0.14704285736400388  Volome and penalty 3.8664014386530643
# Step 319, objective = 3.8664014386530643
# Displacement violation: 0.0   Area penalty 0.08655685689173218  Volome and penalty 3.8635723135505313
# Step 320, objective = 3.8635723135505313
# Displacement violation: 0.0   Area penalty 0.11432722467289104  Volome and penalty 3.8614380099765486
# Step 321, objective = 3.8614380099765486
# Displacement violation: 0.0   Area penalty 0.024451071179891332  Volome and penalty 3.852949668965454
# Step 322, objective = 3.852949668965454
# Displacement violation: 0.0   Area penalty 0.05832733990965545  Volome and penalty 3.844683106295614
# Step 323, objective = 3.844683106295614
# Displacement violation: 0.0   Area penalty 0.11253042607669833  Volome and penalty 3.840303412433282
# Step 324, objective = 3.840303412433282
# Displacement violation: 0.0   Area penalty 0.12563373538691613  Volome and penalty 3.841054436860216
# Step 325, objective = 3.841054436860216
# Displacement violation: 0.0   Area penalty 0.04189517680641019  Volome and penalty 3.8385317379688932
# Step 326, objective = 3.8385317379688932
# Displacement violation: 0.0   Area penalty 0.13237865639246296  Volome and penalty 3.8341932737665947
# Step 327, objective = 3.8341932737665947
# Displacement violation: 0.0   Area penalty 0.06126269260826395  Volome and penalty 3.8283692534143117
# Step 328, objective = 3.8283692534143117
# Displacement violation: 0.0   Area penalty 0.09828557924010765  Volome and penalty 3.8266598895525896
# Step 329, objective = 3.8266598895525896
# Displacement violation: 0.0   Area penalty 0.12086878032657683  Volome and penalty 3.823689283625123
# Step 330, objective = 3.823689283625123
# Displacement violation: 0.0   Area penalty 0.24283951602028866  Volome and penalty 3.8316719756434874
# Step 331, objective = 3.8316719756434874
# Displacement violation: 0.0   Area penalty 0.10009966910144598  Volome and penalty 3.8309848212322066
# Step 332, objective = 3.8309848212322066
# Displacement violation: 0.0   Area penalty 0.07645153976188868  Volome and penalty 3.827186046714022
# Step 333, objective = 3.827186046714022
# Displacement violation: 0.0   Area penalty 0.13507872926148629  Volome and penalty 3.824532381330577
# Step 334, objective = 3.824532381330577
# Displacement violation: 0.0   Area penalty 0.10825433820472732  Volome and penalty 3.822264303277737
# Step 335, objective = 3.822264303277737
# Displacement violation: 0.0   Area penalty 0.06643129590619072  Volome and penalty 3.817047105191581
# Step 336, objective = 3.817047105191581
# Displacement violation: 0.0   Area penalty 0.04713312368342136  Volome and penalty 3.8107428372998844
# Step 337, objective = 3.8107428372998844
# Displacement violation: 0.0   Area penalty 0.019393482147735598  Volome and penalty 3.8007166421869885
# Step 338, objective = 3.8007166421869885
# Displacement violation: 0.0   Area penalty 0.0931856099497137  Volome and penalty 3.7959821305050054
# Step 339, objective = 3.7959821305050054
# Displacement violation: 0.0   Area penalty 0.09421819185786973  Volome and penalty 3.792398501328054
# Step 340, objective = 3.792398501328054
# Displacement violation: 0.0   Area penalty 0.0604524119231523  Volome and penalty 3.7863459836108952
# Step 341, objective = 3.7863459836108952
# Displacement violation: 0.0   Area penalty 0.08517991042318929  Volome and penalty 3.781372486911919
# ...
# Step 887, objective = 2.9750221777014367
# Displacement violation: 0.0   Area penalty 0.11729221381998663  Volome and penalty 2.9775369969029133
# Step 888, objective = 2.9775369969029133
# Displacement violation: 0.0   Area penalty 0.12804745403213927  Volome and penalty 2.9785223679363577
# Step 889, objective = 2.9785223679363577
# Displacement violation: 0.0   Area penalty 0.09105308543149385  Volome and penalty 2.9781419539214267
# Step 890, objective = 2.9781419539214267
# Displacement violation: 0.0   Area penalty 0.09108556593863051  Volome and penalty 2.972401577119438
# Step 891, objective = 2.972401577119438
# Displacement violation: 0.0   Area penalty 0.07304120641925638  Volome and penalty 2.971339143701979
# Step 892, objective = 2.971339143701979
# Displacement violation: 0.0   Area penalty 0.18231727398832703  Volome and penalty 2.973528765878657
# Step 893, objective = 2.973528765878657
# Displacement violation: 0.0   Area penalty 0.04686704735067881  Volome and penalty 2.968073296973877
# Step 894, objective = 2.968073296973877
# Displacement violation: 0.0   Area penalty 0.029873917851263733  Volome and penalty 2.958227242278193
# Step 895, objective = 2.958227242278193
# Displacement violation: 0.0   Area penalty 0.0761044344999321  Volome and penalty 2.9511772668628327
# Step 896, objective = 2.9511772668628327
# Displacement violation: 0.0   Area penalty 0.06618731490398504  Volome and penalty 2.943773177244354
# Step 897, objective = 2.943773177244354
# Displacement violation: 0.0   Area penalty 0.07039136917041186  Volome and penalty 2.9395647553615403
# Step 898, objective = 2.9395647553615403
# Displacement violation: 0.0   Area penalty 0.10534208300687165  Volome and penalty 2.9363295353165593
# Step 899, objective = 2.9363295353165593
# Displacement violation: 0.0   Area penalty 0.04184528308928746  Volome and penalty 2.928296218690327
# Step 900, objective = 2.928296218690327
# Displacement violation: 0.0   Area penalty 0.09639732848569296  Volome and penalty 2.9228401178343915
# Step 901, objective = 2.9228401178343915
# Displacement violation: 0.0   Area penalty 0.10374822460724101  Volome and penalty 2.921157850634491
# Step 902, objective = 2.921157850634491
# Displacement violation: 0.0   Area penalty 0.08622074988670422  Volome and penalty 2.9180098457253254
# Step 903, objective = 2.9180098457253254
# Displacement violation: 0.0   Area penalty 0.06323968595697446  Volome and penalty 2.916636386496143
# Step 904, objective = 2.916636386496143
# Displacement violation: 0.0   Area penalty 0.07043606373014628  Volome and penalty 2.9105671013612247
# Step 905, objective = 2.9105671013612247
# Displacement violation: 0.0   Area penalty 0.017917937171052327  Volome and penalty 2.904011794954241
# Step 906, objective = 2.904011794954241
# Displacement violation: 0.0   Area penalty 0.029830156348764045  Volome and penalty 2.8940119772322914
# Step 907, objective = 2.8940119772322914
# Displacement violation: 0.0   Area penalty 0.07190972681248517  Volome and penalty 2.888524645152137
# Step 908, objective = 2.888524645152137
# Displacement violation: 0.0   Area penalty 0.11540825421833242  Volome and penalty 2.885218460301974
# Step 909, objective = 2.885218460301974
# Displacement violation: 0.0   Area penalty 0.06539235214251551  Volome and penalty 2.87993998753967
# Step 910, objective = 2.87993998753967
# Displacement violation: 0.0   Area penalty 0.07702652606088406  Volome and penalty 2.874246125355493
# Step 911, objective = 2.874246125355493
# Displacement violation: 0.0   Area penalty 0.08456899779120138  Volome and penalty 2.869456610008314
# Step 912, objective = 2.869456610008314
# Displacement violation: 0.0   Area penalty 0.08409514152354779  Volome and penalty 2.865369719989541
# Step 913, objective = 2.865369719989541
# Displacement violation: 0.0   Area penalty 0.06534130302027223  Volome and penalty 2.858117926564181
# Step 914, objective = 2.858117926564181
# Displacement violation: 0.0   Area penalty 0.10061481609131816  Volome and penalty 2.8543680980136505
# Step 915, objective = 2.8543680980136505
# Displacement violation: 0.0   Area penalty 0.03271146776900007  Volome and penalty 2.8472588333357263
# Step 916, objective = 2.8472588333357263
# Displacement violation: 0.0   Area penalty 0.04364961974236419  Volome and penalty 2.8383066001502977
# Step 917, objective = 2.8383066001502977
# Displacement violation: 0.0   Area penalty 0.03703036363767792  Volome and penalty 2.8323707384792582
# Step 918, objective = 2.8323707384792582
# Displacement violation: 0.0   Area penalty 0.08243365806049718  Volome and penalty 2.8272723171789553
# Step 919, objective = 2.8272723171789553
# Displacement violation: 0.0   Area penalty 0.07704826364846301  Volome and penalty 2.8203336307349773
# Step 920, objective = 2.8203336307349773
# Displacement violation: 0.0   Area penalty 0.09894618895136703  Volome and penalty 2.820249923841405
# Step 921, objective = 2.820249923841405
# Displacement violation: 0.0   Area penalty 0.10872540047615199  Volome and penalty 2.8184925678094594
# Step 922, objective = 2.8184925678094594
# Displacement violation: 0.0   Area penalty 0.17583299029529978  Volome and penalty 2.819156375891626
# Step 923, objective = 2.819156375891626
# Displacement violation: 0.0   Area penalty 0.0848687308775962  Volome and penalty 2.8155288067357187
# Step 924, objective = 2.8155288067357187
# Displacement violation: 0.0   Area penalty 0.09926328923295066  Volome and penalty 2.8110332430660034
# Step 925, objective = 2.8110332430660034
# Displacement violation: 0.0   Area penalty 0.10057283242118253  Volome and penalty 2.8089701219357512
# Step 926, objective = 2.8089701219357512
# Displacement violation: 0.0   Area penalty 0.09143164328097139  Volome and penalty 2.8078932380453216
# Step 927, objective = 2.8078932380453216
# Displacement violation: 0.0   Area penalty 0.06476750960493846  Volome and penalty 2.8031239668491303
# Step 928, objective = 2.8031239668491303
# Displacement violation: 0.0   Area penalty 0.1634470417836486  Volome and penalty 2.804438058684654
# Step 929, objective = 2.804438058684654
# Displacement violation: 0.0   Area penalty 0.06960613299748436  Volome and penalty 2.8002733357607346
# Step 930, objective = 2.8002733357607346
# Displacement violation: 0.0   Area penalty 0.1273653498913282  Volome and penalty 2.802214814092972
# Step 931, objective = 2.802214814092972
# Displacement violation: 0.0   Area penalty 0.12149998318485655  Volome and penalty 2.8006210870080746
# Step 932, objective = 2.8006210870080746
# Displacement violation: 0.0   Area penalty 0.06989130698300366  Volome and penalty 2.798535291839268
# Step 933, objective = 2.798535291839268
# Displacement violation: 0.0   Area penalty 0.08582238352978011  Volome and penalty 2.7946827221412427
# Step 934, objective = 2.7946827221412427
# Displacement violation: 0.0   Area penalty 0.15013255092115493  Volome and penalty 2.7927726991770085
# Step 935, objective = 2.7927726991770085
# Displacement violation: 0.0   Area penalty 0.06883572909881755  Volome and penalty 2.7888160746936603
# Step 936, objective = 2.7888160746936603
# Displacement violation: 0.0   Area penalty 0.16853520996038324  Volome and penalty 2.7914338184525804
# Step 937, objective = 2.7914338184525804
# Displacement violation: 0.0   Area penalty 0.12739298485266237  Volome and penalty 2.7946113043762164
# Step 938, objective = 2.7946113043762164
# Displacement violation: 0.0   Area penalty 0.18345204470313276  Volome and penalty 2.797169054060424
# Step 939, objective = 2.797169054060424
# Displacement violation: 0.0   Area penalty 0.16520223911641502  Volome and penalty 2.799632509393305
# Step 940, objective = 2.799632509393305
# Displacement violation: 0.0   Area penalty 0.19280400541056902  Volome and penalty 2.803850166644575
# Step 941, objective = 2.803850166644575
# Displacement violation: 0.0   Area penalty 0.21842138204491124  Volome and penalty 2.8106987270893296
# Step 942, objective = 2.8106987270893296
# Displacement violation: 0.0   Area penalty 0.37073797820659027  Volome and penalty 2.8317751610350124
# Step 943, objective = 2.8317751610350124
# Displacement violation: 0.0   Area penalty 0.1971784820773716  Volome and penalty 2.8453479530954366
# Step 944, objective = 2.8453479530954366
# Displacement violation: 0.0   Area penalty 0.1733831649231393  Volome and penalty 2.8484725227164
# Step 945, objective = 2.8484725227164
# Displacement violation: 0.0   Area penalty 0.18479040524699514  Volome and penalty 2.8522831893245124
# Step 946, objective = 2.8522831893245124
# Displacement violation: 0.0   Area penalty 0.11526577049397284  Volome and penalty 2.853078575054147
# Step 947, objective = 2.853078575054147
# Displacement violation: 0.0   Area penalty 0.07587328223849688  Volome and penalty 2.8497675669834472
# Step 948, objective = 2.8497675669834472
# Displacement violation: 0.0   Area penalty 0.0944727826310721  Volome and penalty 2.848241671215267
# Step 949, objective = 2.848241671215267
# Displacement violation: 0.0   Area penalty 0.15270930070461589  Volome and penalty 2.8499893536491085
# Step 950, objective = 2.8499893536491085
# Displacement violation: 0.0   Area penalty 0.08585743956694855  Volome and penalty 2.847497680465829
# Step 951, objective = 2.847497680465829
# Displacement violation: 0.0   Area penalty 0.10026431558131116  Volome and penalty 2.8442107683031375
# Step 952, objective = 2.8442107683031375
# Displacement violation: 0.0   Area penalty 0.17913996561681705  Volome and penalty 2.8467656723081984
# Step 953, objective = 2.8467656723081984
# Displacement violation: 0.0   Area penalty 0.1646286603551244  Volome and penalty 2.851605167318957
# Step 954, objective = 2.851605167318957
# Displacement violation: 0.0   Area penalty 0.18487135850578834  Volome and penalty 2.8613006221945945
# Step 955, objective = 2.8613006221945945
# Displacement violation: 0.0   Area penalty 0.19273075948472185  Volome and penalty 2.8668166234932837
# Step 956, objective = 2.8668166234932837
# Displacement violation: 0.0   Area penalty 0.2566853298181017  Volome and penalty 2.8757172252547827
# Step 957, objective = 2.8757172252547827
# Displacement violation: 0.0   Area penalty 0.12621271198057893  Volome and penalty 2.8839544149245584
# Step 958, objective = 2.8839544149245584
# Displacement violation: 0.0   Area penalty 0.00646930532930375  Volome and penalty 2.8787954148741206
# Step 959, objective = 2.8787954148741206
# Displacement violation: 0.0   Area penalty 0.044702674383483576  Volome and penalty 2.8695180202424657
# Step 960, objective = 2.8695180202424657
# Displacement violation: 0.0   Area penalty 0.09991930408491803  Volome and penalty 2.865857575461268
# Step 961, objective = 2.865857575461268
# Displacement violation: 0.0   Area penalty 0.07918473960114128  Volome and penalty 2.8604871172826574
# Step 962, objective = 2.8604871172826574
# Displacement violation: 0.0   Area penalty 0.06713639640570748  Volome and penalty 2.855536897920735
# Step 963, objective = 2.855536897920735
# Displacement violation: 0.0   Area penalty 0.09311979790174095  Volome and penalty 2.852271097952567
# Step 964, objective = 2.852271097952567
# Displacement violation: 0.0   Area penalty 0.05145092127998145  Volome and penalty 2.8468452557364436
# Step 965, objective = 2.8468452557364436
# Displacement violation: 0.0   Area penalty 0.142161901313753  Volome and penalty 2.8447997588443252
# Step 966, objective = 2.8447997588443252
# Displacement violation: 0.0   Area penalty 0.09314793075635663  Volome and penalty 2.84230027663834
# Step 967, objective = 2.84230027663834
# Displacement violation: 0.0   Area penalty 0.06026927323926709  Volome and penalty 2.8357853674754745
# Step 968, objective = 2.8357853674754745
# Displacement violation: 0.0   Area penalty 0.08358783635382122  Volome and penalty 2.830257169643847
# Step 969, objective = 2.830257169643847
# Displacement violation: 0.0   Area penalty 0.0750029024278729  Volome and penalty 2.826075633174812
# Step 970, objective = 2.826075633174812
# Displacement violation: 0.0   Area penalty 0.11229242951887548  Volome and penalty 2.8240252919870756
# Step 971, objective = 2.8240252919870756
# Displacement violation: 0.0   Area penalty 0.08240679563284803  Volome and penalty 2.8206208749947477
# Step 972, objective = 2.8206208749947477
# Displacement violation: 0.0   Area penalty 0.16918576751273146  Volome and penalty 2.8247563533241324
# Step 973, objective = 2.8247563533241324
# Displacement violation: 0.0   Area penalty 0.1855462910740901  Volome and penalty 2.8297327561970307
# Step 974, objective = 2.8297327561970307
# Displacement violation: 0.0   Area penalty 0.11579838267008494  Volome and penalty 2.828618638601321
# Step 975, objective = 2.828618638601321
# Displacement violation: 0.0   Area penalty 0.13571738355049265  Volome and penalty 2.828072087221008
# Step 976, objective = 2.828072087221008
# Displacement violation: 0.0   Area penalty 0.09294834739195781  Volome and penalty 2.8249835834560293
# Step 977, objective = 2.8249835834560293
# Displacement violation: 0.0   Area penalty 0.12359309413660276  Volome and penalty 2.822623848655334
# Step 978, objective = 2.822623848655334
# Displacement violation: 0.0   Area penalty 0.22552626986670948  Volome and penalty 2.8243681629547175
# Step 979, objective = 2.8243681629547175
# Displacement violation: 0.0   Area penalty 0.06478233286884832  Volome and penalty 2.8232121417242633
# Step 980, objective = 2.8232121417242633
# Displacement violation: 0.0   Area penalty 0.1343468896411461  Volome and penalty 2.8208380121837116
# Step 981, objective = 2.8208380121837116
# Displacement violation: 0.0   Area penalty 0.11266197642142889  Volome and penalty 2.821319783940084
# Step 982, objective = 2.821319783940084
# Displacement violation: 0.0   Area penalty 0.08237657046208464  Volome and penalty 2.8167845557477653
# Step 983, objective = 2.8167845557477653
# Displacement violation: 0.0   Area penalty 0.10238066575173069  Volome and penalty 2.8141002675950113
# Step 984, objective = 2.8141002675950113
# Displacement violation: 0.0   Area penalty 0.17303184817222075  Volome and penalty 2.8185946562408843
# Step 985, objective = 2.8185946562408843
# Displacement violation: 0.0   Area penalty 0.05824825657118931  Volome and penalty 2.813366777719278
# Step 986, objective = 2.813366777719278
# Displacement violation: 0.0   Area penalty 0.10817757274946659  Volome and penalty 2.8077217667664978
# Step 987, objective = 2.8077217667664978
# Displacement violation: 0.0   Area penalty 0.06519773802558294  Volome and penalty 2.8049169041082362
# Step 988, objective = 2.8049169041082362
# Displacement violation: 0.0   Area penalty 0.030867766592915437  Volome and penalty 2.7963893853311497
# Step 989, objective = 2.7963893853311497
# Displacement violation: 0.0   Area penalty 0.03977912666649086  Volome and penalty 2.790345155916128
# Step 990, objective = 2.790345155916128
# Displacement violation: 0.0   Area penalty 0.04879264558193706  Volome and penalty 2.784740194924711
# Step 991, objective = 2.784740194924711
# Displacement violation: 0.0   Area penalty 0.1301510306015566  Volome and penalty 2.782703523033515
# Step 992, objective = 2.782703523033515
# Displacement violation: 0.0   Area penalty 0.13946985189695932  Volome and penalty 2.7861932230908923
# Step 993, objective = 2.7861932230908923
# Displacement violation: 0.0   Area penalty 0.13346260163006435  Volome and penalty 2.782427800935957
# Step 994, objective = 2.782427800935957
# Displacement violation: 0.0   Area penalty 0.09355444138673609  Volome and penalty 2.7801363866316118
# Step 995, objective = 2.7801363866316118
# Displacement violation: 0.0   Area penalty 0.1425255018832905  Volome and penalty 2.7791519842342227
# Step 996, objective = 2.7791519842342227
# Displacement violation: 0.0   Area penalty 0.05561266857105571  Volome and penalty 2.7751699187906778
# Step 997, objective = 2.7751699187906778
# Displacement violation: 0.0   Area penalty 0.08285641667414818  Volome and penalty 2.7699500348222976
# Step 998, objective = 2.7699500348222976
# Displacement violation: 0.0   Area penalty 0.11566539338128867  Volome and penalty 2.768024665660469
# Step 999, objective = 2.768024665660469
# Stopping criteria 'maxiter' met, end of optimization

# %%
np.pi*(d/4)**2/4
# Out:
# 0.001963495408493621

# %%
np.min(sso_model.parameter_values)
# Out:
# Array(0.00048612, dtype=float64)

# %%
np.max(sso_model.parameter_values)
# Out:
# Array(0.00330792, dtype=float64)

# %%
iteration = np.arange(0,len(W_list),1)


fig, ax1 = plt.subplots()

color = 'k'
ax1.set_xlabel('Iteartion')
ax1.set_ylabel('Strain energy',color=color)
ax1.plot(iteration, SE_list, color=color)
ax1.tick_params(axis='y', labelcolor=color)
#ax1.set_yticks(np.linspace(0,70000,8))

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel(r'Volume ($m^3$)', color=color)  # we already handled the x-label with ax1
ax2.plot(iteration, W_list, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
iteration = np.arange(0,len(W_list),1)


fig, ax1 = plt.subplots()

color = 'k'
ax1.set_xlabel('Iteartion')
ax1.set_ylabel('Maximum vertical displacement (cm)',color=color)
ax1.plot(iteration, np.array(u_max_list), color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_yticks(np.linspace(0,0.10,5))

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel(r'Volume ($m^3$)', color=color)  # we already handled the x-label with ax1
ax2.plot(iteration, W_list, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
iteration = np.arange(0,len(W_list),1)


fig, ax1 = plt.subplots()

color = 'k'
ax1.set_xlabel('Iteartion')
ax1.set_ylabel('Strain energy',color=color)
ax1.plot(iteration, SE_list, color=color)
ax1.tick_params(axis='y', labelcolor=color)
#ax1.set_yticks(np.linspace(0,70000,8))

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel(r'Volume ($m^3$)', color=color)  # we already handled the x-label with ax1
ax2.plot(iteration, W_list, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
iteration = np.arange(0,len(W_list),1)


fig, ax1 = plt.subplots()

color = 'k'
ax1.set_xlabel('Iteartion')
ax1.set_ylabel('Maximum vertical displacement (cm)',color=color)
ax1.plot(iteration, np.array(u_max_list), color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel(r'Volume ($m^3$)', color=color)  # we already handled the x-label with ax1
ax2.plot(iteration, W_list, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
from matplotlib.collections import LineCollection
import matplotlib as mpl
cmap = mpl.colormaps['Blues']

# %%
fig, (ax1, ax2) = plt.subplots(2, 1,figsize=(15, 15))

ax1.set_title('Unoptimized structure')
ax1.set_xlabel('X (m)',fontsize=15)
ax1.set_ylabel('Y (m)',fontsize=15)
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.tick_params(axis='both', which='minor', labelsize=14)
#Plot a basic wireframe.
for i in range(n_ele):
  ax1.plot([x_ele[i,0],x_ele[i,1]],[y_ele[i,0],y_ele[i,1]],color=cmap(1),linewidth=5.0)

ax1.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],color='black',label='Non-design nodes')
ax1.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],s=150,marker='^',alpha=0.2,color='black')

ax1.legend(fontsize=17, loc=(0.5,0.1))

ax2.set_title('Size-optimized structure')
ax2.set_xlabel('X (m)',fontsize=15)
ax2.set_ylabel('Y (m)',fontsize=15)
ax2.tick_params(axis='both', which='major', labelsize=14)
ax2.tick_params(axis='both', which='minor', labelsize=14)
#Plot a basic wireframe.
for i in range(n_ele):
    lw=5.0 * A_opt[i]/A
    alpha = float(A_opt[i]/A)
    ax2.plot([x_ele[i,0],x_ele[i,1]],[y_ele[i,0],y_ele[i,1]],color=cmap(alpha),linewidth=lw)

cb = plt.colorbar(mpl.cm.ScalarMappable( cmap=cmap), ax=ax2)
cb.ax.tick_params(labelsize=20)
ax2.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],color='black',label='Non-design nodes')
ax2.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],s=150,marker='^',alpha=0.2,color='black')

ax1.legend(fontsize=17, loc=(0.5,0.1))
plt.show()

# %%
#Setup colormap
cmap = plt.get_cmap('viridis')
norm = plt.Normalize(0, np.max(A_opt))

segs = []
colors = []
for i in range(n_ele):
    line = [(x_ele[i,0],y_ele[i,0]),(x_ele[i,1],y_ele[i,1])]
    segs.append(line)
    colors.append(cmap(norm(A)))

LC = LineCollection(segs,color=colors,linewidths=5.0)

# %%
segs = []
colors = []
lws = []
for i in range(n_ele):
    lw=5.0 * A_opt[i]/A
    line_colors = cmap(norm(A_opt[i]))
    line = [(x_ele[i,0],y_ele[i,0]),(x_ele[i,1],y_ele[i,1])]
    segs.append(line)
    colors.append(line_colors)
    lws.append(lw)

LC2 = LineCollection(segs,color=colors,linewidths=lws)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1,figsize=(15, 15))




ax1.set_title('Unoptimized structure')
ax1.set_xlabel('X (m)',fontsize=15)
ax1.set_ylabel('Y (m)',fontsize=15)
ax1.tick_params(axis='both', which='major', labelsize=14)
ax1.tick_params(axis='both', which='minor', labelsize=14)
#Plot a basic wireframe.
for i in range(n_ele):
    line_colors = cmap(norm(A))
    ax1.plot([x_ele[i,0],x_ele[i,1]],[y_ele[i,0],y_ele[i,1]],color=line_colors,linewidth=5.0)

ax1.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],color='black',label='Non-design nodes')
ax1.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],s=150,marker='^',alpha=0.2,color='black')

ax1.legend(fontsize=17, loc=(0.5,0.1))


ax2.set_title('Size-optimized structure')
ax2.set_xlabel('X (m)',fontsize=15)
ax2.set_ylabel('Y (m)',fontsize=15)
ax2.tick_params(axis='both', which='major', labelsize=14)
ax2.tick_params(axis='both', which='minor', labelsize=14)
#Plot a basic wireframe.
for i in range(n_ele):
    lw=5.0 * A_opt[i]/A
    line_colors = cmap(norm(A_opt[i]))
    ax2.plot([x_ele[i,0],x_ele[i,1]],[y_ele[i,0],y_ele[i,1]],color=line_colors,linewidth=lw)

ax2.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],color='black',label='Non-design nodes')
ax2.scatter(x_nodes[non_design_nodes],y_nodes[non_design_nodes],s=150,marker='^',alpha=0.2,color='black')

ax1.legend(fontsize=17, loc=(0.5,0.1))
plt.show()
